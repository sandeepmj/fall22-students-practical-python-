# %% [markdown]
# # Scraping homework
#
# - Scrape a webpage with tabular data
# - Scrape a page with organized, clean html

# %% [markdown]
# ## Tabular data scrape
#
# 1. Scrape the data on this page: https://www.uscourts.gov/judges-judgeships/judicial-vacancies/confirmation-listing
#
# 2. Turn the captured table into a dataframe
#
# 3. Export the dataframe

# %%
## Create as many cells as you need.

# %% [markdown]
# ## Scrape a page with organized, clean html
#
# Scrape this <a href="https://sandeepmj.github.io/scrape-example-page/homework-site.html">mockup site</a> that lists a few data points for addiction centers.

# %%
## capture the contents of the site in a response object

# %%
## generate and print soup

# %%
## check data type of soup

# %%
### Return the name of the first center (including the html)

# %%
### Return only the name of the first center (remove all the html)

# %% [markdown]
# ### Find first instance of ALL a center's data
# ### Think of this as the first group of data associated with a company
# ![Screen%20Shot%202022-09-19%20at%208.27.05%20PM.png](attachment:Screen%20Shot%202022-09-19%20at%208.27.05%20PM.png)

# %%
#### Find all the instances of every centers' data points.

# %%
### Find all the registration data

# %% [markdown]
# ### Place all the registration data into a list with only the numbers in the format.
# It should look like this:
#
# ```['4235', '4234', '4231']```

# %%
## do it here (create more cells if you need them)

# %% [markdown]
# ### Place all the company names into a list.
# It should look like this:
#
# ```['Recovery Foundation','New Horizons','Renewable Light']```

# %%
## do it here (create more cells if you need them)

# %%
### Do the same but via list comprehension

# %% [markdown]
# ### Place all the cost into a list.
# It should look like this:
#
# ```['$10,000', '$15,000', '$11,000']```

# %%
## do it here (create more cells if you need them)

# %% [markdown]
# ### Place all the inspection results into a list.
# It should look like this:
#
# ```['Passed', 'Failed', 'Passed']```

# %%
## Turn these 4 lists into a dataframe

# %%
## export the dataframe to a csv file.
